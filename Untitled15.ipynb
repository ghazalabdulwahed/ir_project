# %%
import pandas as pd
df = pd.read_csv("quora_cleaned_sample.csv")
df.head()
# Out:
#    doc_id                                      original_text  \
# 0       1  What is the step by step guide to invest in sh...
# 1       2  What is the step by step guide to invest in sh...
# 2       3  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 3       4  What would happen if the Indian government sto...
# 4       5  How can I increase the speed of my internet co...
#
#                                         cleaned_text
# 0          step step guide invest share market india
# 1                step step guide invest share market
# 2                             story kohinoor diamond
# 3  would happen indian government stole kohinoor ...
# 4       increase speed internet connection using vpn

# %%
from collections import defaultdict

inverted_index = defaultdict(set)

for _, row in df.iterrows():
    doc_id = row['doc_id']

    text = str(row['cleaned_text'])
    words = text.split()

    for word in words:
        inverted_index[word].add(doc_id)

print(" تم بناء الفهرس المعكوس بنجاح")
print("عدد الكلمات المميزة:", len(inverted_index))
# Out:
#  تم بناء الفهرس المعكوس بنجاح
# عدد الكلمات المميزة: 10195

# %%
print("أول 5 كلمات من الفهرس المعكوس:")

for word, doc_ids in list(inverted_index.items())[:5]:
    print(f"{word} -> {len(doc_ids)} وثيقة")
# Out:
# أول 5 كلمات من الفهرس المعكوس:
# step -> 8 وثيقة
# guide -> 2 وثيقة
# invest -> 18 وثيقة
# share -> 20 وثيقة
# market -> 28 وثيقة

# %%
import math
from collections import Counter

tf_docs = {}

for _, row in df.iterrows():

    doc_id = row['doc_id']

    words = str(row['cleaned_text']).split()

    counts = Counter(words)

    tf_docs[doc_id] = {
        word: math.log(1 + count)
        for word, count in counts.items()
    }

print("تم حساب TF")
# Out:
# تم حساب TF

# %%
import math

N = len(df)

df_counts = {
    word: len(doc_ids)
    for word, doc_ids in inverted_index.items()
}

idf = {
    word: math.log(1 + (N / df_t))
    for word, df_t in df_counts.items()
}

print("تم حساب IDF")
# Out:
# تم حساب IDF

# %%
tfidf_docs = {}

for doc_id, tf_dict in tf_docs.items():

    tfidf_docs[doc_id] = {
        word: tf_value * idf[word]
        for word, tf_value in tf_dict.items()
    }

print("تم حساب TF-IDF")
# Out:
# تم حساب TF-IDF

# %%
first_doc_id = df['doc_id'].iloc[0]

print(f"TF للوثيقة {first_doc_id}:\n")

for word, score in list(tf_docs[first_doc_id].items())[:5]:
    print(f"{word}: {score:.4f}")
# Out:
# TF للوثيقة 1:
#
# step: 1.0986
# guide: 0.6931
# invest: 0.6931
# share: 0.6931
# market: 0.6931

# %%
print("أول 5 كلمات مع قيم IDF:\n")

for word, score in list(idf.items())[:5]:
    print(f"{word}: {score:.4f}")
# Out:
# أول 5 كلمات مع قيم IDF:
#
# step: 7.1307
# guide: 8.5164
# invest: 6.3208
# share: 6.2156
# market: 5.8799

# %%
first_doc_id = df['doc_id'].iloc[0]

print(f"TF-IDF للوثيقة {first_doc_id}:\n")

for word, score in list(tfidf_docs[first_doc_id].items())[:5]:
    print(f"{word}: {score:.4f}")
# Out:
# TF-IDF للوثيقة 1:
#
# step: 7.8339
# guide: 5.9031
# invest: 4.3812
# share: 4.3083
# market: 4.0757

# %%
doc_lengths = {}

for _, row in df.iterrows():
    doc_id = row['doc_id']
    words = row['cleaned_text'].split()
    doc_lengths[doc_id] = len(words)

avg_doc_length = sum(doc_lengths.values()) / len(doc_lengths)

print("متوسط طول الوثائق:")
print(avg_doc_length)
# Out:
# متوسط طول الوثائق:
# 5.449549549549549

# %%
df_counts = {}

for word, docs in inverted_index.items():
    df_counts[word] = len(docs)

print("عدد الكلمات:", len(df_counts))
# Out:
# عدد الكلمات: 10195

# %%
import math

N = len(df)

bm25_idf = {}

for term, df_term in df_counts.items():
    bm25_idf[term] = math.log(
        ((N - df_term + 0.5) / (df_term + 0.5)) + 1
    )

print("تم حساب BM25 IDF")
# Out:
# تم حساب BM25 IDF

# %%
from collections import Counter

def bm25_search_fast(query, k1=1.5, b=0.75):
    scores = {}
    query_terms = query.lower().split()
    candidate_docs = set()
    for term in query_terms:
        if term in inverted_index:
            candidate_docs.update(inverted_index[term])
            

    for doc_id in candidate_docs:

        doc_row = df[df['doc_id'] == doc_id].iloc[0]
        words = str(doc_row['cleaned_text']).split()
        
        doc_len = len(words)
        term_freqs = Counter(words)
        score = 0
        
        for term in query_terms:
            if term not in term_freqs:
                continue
                
            tf = term_freqs[term]
            idf = bm25_idf.get(term, 0)
            
            numerator = tf * (k1 + 1)
            denominator = tf + k1 * (1 - b + b * (doc_len / avg_doc_length))
            
            score += idf * (numerator / denominator)
            
        scores[doc_id] = score

    ranked_docs = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    return ranked_docs

# %%
results = bm25_search_fast(
    "machine learning",
    k1=1.5,
    b=0.75
)

print("أفضل 10 نتائج:\n")

for doc_id, score in results[:10]:
    print(doc_id, round(score, 4))
# Out:
# أفضل 10 نتائج:
#
# 249 14.2021
# 6628 13.9496
# 4598 12.8699
# 6627 12.1936
# 1614 11.7662
# 1174 11.7662
# 1175 11.7662
# 1613 10.8369
# 10167 10.0436
# 4597 10.0436

# %%
results1 = bm25_search_fast(
    "machine learning",
    k1=1.2,
    b=0.5
)

results2 = bm25_search_fast(
    "machine learning",
    k1=2.0,
    b=0.9
)

print(results1[:5])
print()
print(results2[:5])
# Out:
# [(6628, 13.491888202847846), (249, 12.91235019686731), (6627, 12.43460734786488), (4598, 12.215595495098317), (1614, 11.590185252506185)]
#
# [(249, 15.513335690163052), (6628, 14.493891055953302), (4598, 13.480941015198734), (6627, 12.098261150061369), (1614, 11.919387739123467)]
