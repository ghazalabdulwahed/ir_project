# %%
import pandas as pd
from collections import defaultdict

# %%
df = pd.read_csv(
    "quora_cleaned_sample.csv"
)

# %%
from retrieval_service import (
    build_inverted_index,
    prepare_bm25,
    bm25_search
)

# %%
inverted_index = build_inverted_index(df)

bm25_idf, avg_doc_length = prepare_bm25(
    df,
    inverted_index
)

# %%
from embedding_service import SemanticSearchService

# %%
import os

print(os.path.exists("quora_embeddings.npy"))
# Out:
# True

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "sentence-transformers/all-MiniLM-L6-v2",
    local_files_only=True
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
search_service = SemanticSearchService()

search_service.initialize_service(
    load_embeddings=True
)
# Out:
# ====== [Initialization] ======
# Loading Model: sentence-transformers/all-MiniLM-L6-v2...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model Loaded Successfully.
# Reading Data from: quora_cleaned_sample.csv...
# Data Loaded Successfully. Shape: (9990, 3)
# Loading Pre-computed Embeddings from: quora_embeddings.npy...
# Embeddings Loaded. Shape: (9990, 384)

# %%
from collections import defaultdict

def reciprocal_rank_fusion(
    bm25_results,
    bert_results,
    k=60
):
    fused_scores = defaultdict(float)

    # نتائج BM25
    for rank, (doc_id, score) in enumerate(
        bm25_results,
        start=1
    ):
        fused_scores[doc_id] += 1 / (k + rank)

    # نتائج BERT
    for rank, result in enumerate(
        bert_results,
        start=1
    ):
        doc_id = result["doc_id"]

        fused_scores[doc_id] += 1 / (k + rank)

    final_results = sorted(
        fused_scores.items(),
        key=lambda x: x[1],
        reverse=True
    )

    return final_results

# %%
query = "machine learning"

bm25_results = bm25_search(
    query,
    df,
    inverted_index,
    bm25_idf,
    avg_doc_length
)

bert_results = search_service.search_semantic(
    query,
    top_k=100
)

hybrid_results = reciprocal_rank_fusion(
    bm25_results[:100],
    bert_results
)

# %%
print(hybrid_results[:10])
# Out:
# [(249, 0.03278688524590164), (6628, 0.0315136476426799), (4598, 0.03149801587301587), (1175, 0.030798389007344232), (10167, 0.030621785881252923), (1614, 0.029877369007803793), (6627, 0.0293236301369863), (1174, 0.029236022193768675), (4597, 0.029211087420042643), (7607, 0.027972027972027972)]

# %%
for rank, (doc_id, score) in enumerate(
    hybrid_results[:10],
    start=1
):
    print(
        f"Rank {rank} | Doc ID: {doc_id} | RRF Score: {score:.6f}"
    )
# Out:
# Rank 1 | Doc ID: 249 | RRF Score: 0.032787
# Rank 2 | Doc ID: 6628 | RRF Score: 0.031514
# Rank 3 | Doc ID: 4598 | RRF Score: 0.031498
# Rank 4 | Doc ID: 1175 | RRF Score: 0.030798
# Rank 5 | Doc ID: 10167 | RRF Score: 0.030622
# Rank 6 | Doc ID: 1614 | RRF Score: 0.029877
# Rank 7 | Doc ID: 6627 | RRF Score: 0.029324
# Rank 8 | Doc ID: 1174 | RRF Score: 0.029236
# Rank 9 | Doc ID: 4597 | RRF Score: 0.029211
# Rank 10 | Doc ID: 7607 | RRF Score: 0.027972

# %%
for rank, (doc_id, score) in enumerate(
    hybrid_results[:5],
    start=1
):
    row = df[df["doc_id"] == doc_id].iloc[0]

    print(f"Rank {rank}")
    print(f"Doc ID: {doc_id}")
    print(f"RRF Score: {score:.6f}")
    print(row["cleaned_text"][:200])
    print("-"*50)
# Out:
# Rank 1
# Doc ID: 249
# RRF Score: 0.032787
# alternative machine learning
# --------------------------------------------------
# Rank 2
# Doc ID: 6628
# RRF Score: 0.031514
# deep learning important machine learning
# --------------------------------------------------
# Rank 3
# Doc ID: 4598
# RRF Score: 0.031498
# machine learning used finance
# --------------------------------------------------
# Rank 4
# Doc ID: 1175
# RRF Score: 0.030798
# undergraduate help machine learning research
# --------------------------------------------------
# Rank 5
# Doc ID: 10167
# RRF Score: 0.030622
# study formal methods artificial intelligence machine learning
# --------------------------------------------------
